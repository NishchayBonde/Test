# %% [markdown]
# # New Multi-bot system

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage
from langchain.llms import OpenAI
from langchain import PromptTemplate
from langchain.chains import SequentialChain
from langchain.chains import ConversationChain
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.document_loaders import UnstructuredPDFLoader, OnlinePDFLoader, PyPDFLoader, TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import ConversationalRetrievalChain
from langchain.vectorstores import Chroma, Pinecone
from langchain.embeddings.openai import OpenAIEmbeddings
import os
from langchain.memory import ConversationBufferMemory
from langchain.agents import load_tools, initialize_agent, AgentType
import ast
import openai
# Set up OpenAI API credentials
os.environ["OPENAI_API_KEY"] = "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"
openai.api_key='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'
os.environ["SERPAPI_API_KEY"] = "f7bbe11ca6d5cecd0b83065f649b5a12a0dca43ba4b829452dfe70cc4e62b20a"

tools = load_tools(["serpapi"], llm=OpenAI(temperature=0,max_tokens=200))
agent = initialize_agent(tools, llm=OpenAI(temperature=0,max_tokens=200), agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION) 
# load Taxonomy
loader = TextLoader("Taxonomy.txt", encoding="utf-8")
taxonomy = loader.load()

# split the documents into chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(taxonomy)
# select which embeddings we want to use
embeddings = OpenAIEmbeddings()
# create the vectorestore to use as the index
db = Chroma.from_documents(texts, embeddings)
# expose this index in a retriever interface
retriever = db.as_retriever(search_type="similarity", search_kwargs={"k":2})
# create a memory object, which is neccessary to track the inputs/outputs and hold a conversation.
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
# create a chain to answer questions 
qa = ConversationalRetrievalChain.from_llm(OpenAI(temperature=0,max_tokens=200), retriever=retriever, memory=memory) # , memory=memory
chat_history = []
User_query = input('Please enter the query: ')

result = qa({"question": User_query})  # , "chat_history": chat_history

def process_block(block):
    role_mapping = {
        'HumanMessage': 'user',
        'AIMessage': 'assistant'
    }

    result = []

    for message in block:
        role = role_mapping.get(type(message).__name__, type(message).__name__.lower())
        content = message.content.strip()
        result.append({'role': role, 'content': content})

    return result


def chat(messages):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        max_tokens=200,
        temperature=0
    )
#   response.choices[0].message["content"]
    return response.choices[0].message['content']

b1_content="""

You are the Associate and your role is to execute instructions of Manager which is another chatbot .
"""

b2_content="""

You are the Manager and your role is to manager your associate Bot B, which is another chatbot.Generate prompts to guide your associate \
step by step to address user's request. You keep the conversation going with Associate trying to deep dive into the topic and consider the following conversation as well to see how can Bot A answer in a better way
"""

b3_content="""

You are Supervisor. You are the Judge of this discussion, you evaluate the responses
and judge from scale 1 to 5 and give the score without any explanation based on below criteria :
If the response from Bot A is getting repeated or  \
there is no relevance to context or Bot A says "I don't know" then give score 2 or below.\
If the conversation is very good covering all points only then give score 5\
Your response should only be a number 1, 2, 3, 4, or 5

"""

# Initialize the chatbots
bot1_prompt = [{'role':'system', 'content': b1_content}]
bot2_prompt = [{'role':'system', 'content': b2_content}]
bot3_prompt = [{'role':'system', 'content': b3_content}]

# Get the initial context from the user
# context = [{'role':'user', 'content':result["answer"]}]
memory.save_context({'input': User_query},{"output": result["answer"]})
#result = qa({"question": bot1_prompt, "chat_history": context})

# Initialize the conversation tree
tree = []
bot2_response= ""
#bot1_response= []
# Chat loop
while True:
    # Bot 1 uses conversation retreival chain to generate response
    #chat_history = [(User_query, result["answer"])]   # 
    #chat_history = [(b1_content, result["answer"])]
    
#     chat_history = [(b1_content, result["answer"])] + [(bot1_response, bot2_response)]
    # Added web search result to bot A response
    chat_history = [(bot1_prompt[0]['content'], result["answer"])]
    bot1_response = bot1_prompt + qa({"question": bot2_response})["answer"] + agent.run(bot2_response)
    print("Associate:", bot1_response)

    # Bot 2 questions to Bot 1
    
    messages = bot2_prompt + process_block(memory.load_memory_variables(())['chat_history'])  # + context
    bot2_response = chat(messages)
    # memory.save_context({'input': bot2_prompt},{"output": bot2_response})
    print("Manager:", bot2_response)
    
    # Bot 3 rates the conversation and gives response from 1 to 5
    
    messages = [{'role':'assistant', 'content':bot1_response}] + [{'role':'assistant', 'content':bot2_response}] + bot3_prompt
    bot3_response = chat(messages)
    print("Supervisor:", bot3_response)
    
    # Web Search bot gives reply to bot_2
    
#     bot4_response = agent.run(bot2_response)
#     memory.save_context({'input': bot2_response},{"output": bot4_response})
#     print("Bot D:", bot4_response)

    # Add the conversation to the tree
    tree.append(bot1_response)
    tree.append(bot2_response)
    tree_C = bot3_response
    
    # Check if the tree of thought has reached its end
    # if len(tree) >= 10:
    #   print("The tree of thought has reached its end.")
    #   break
    if tree_C == '5':
        print("The desired outcome is received as below: \n", "\n".join(tree_A))
        break
    if tree_C == '2' or tree_C == '1':
        User_input = input("Need Human intervention to keep the conversation going else enter 'stop' to exit ")
        if User_input.lower() == "stop":
            break
        else:
            bot2_response = User_input
            continue
# Out:
# Created a chunk of size 1110, which is longer than the specified 1000
# Created a chunk of size 2555, which is longer than the specified 1000
# Created a chunk of size 2649, which is longer than the specified 1000
# Created a chunk of size 1114, which is longer than the specified 1000
# Created a chunk of size 4118, which is longer than the specified 1000
# Created a chunk of size 8955, which is longer than the specified 1000
# Created a chunk of size 3413, which is longer than the specified 1000
# Created a chunk of size 4122, which is longer than the specified 1000
# Created a chunk of size 4813, which is longer than the specified 1000
# Created a chunk of size 3396, which is longer than the specified 1000
# Created a chunk of size 3144, which is longer than the specified 1000
# Created a chunk of size 2505, which is longer than the specified 1000
# Created a chunk of size 3822, which is longer than the specified 1000
# ...

# %% [markdown]
# # Using Web Search for answering

# %%
llm=OpenAI(temperature=0,max_tokens=200)

tools = load_tools(["serpapi"],llm=llm)
chat_history=[]

PREFIX = '''You are the Associate and your role is to execute instructions of Manager which is another chatbot. You are excellent in giving detailed answers.
'''

SUFFIX = '''

Begin!


Instructions: {input}
{agent_scratchpad}
'''

agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent="zero-shot-react-description",
#     verbose=True,
#     return_intermediate_steps=True,
    agent_kwargs={
        'prefix': PREFIX,
#         'format_instructions': FORMAT_INSTRUCTIONS,
         'suffix': SUFFIX
     }
)

User_query = input('Please enter the query: ')

result = agent({"input": User_query.strip(),"agent_scratchpad":[], "chat_history": []})
result['output']
# Out:
# Please enter the query: what are types of investments
# 'The three main types of investments are equity, fixed-income and cash or cash equivalents. Equity investments include stocks, mutual funds, and exchange-traded funds. Fixed-income investments include bonds, certificates of deposit, and money market accounts. Cash or cash equivalents include savings accounts, money market funds, and short-term treasury bills.'

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage
from langchain.llms import OpenAI
from langchain import PromptTemplate
from langchain.chains import SequentialChain
from langchain.chains import ConversationChain
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.document_loaders import UnstructuredPDFLoader, OnlinePDFLoader, PyPDFLoader, TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import ConversationalRetrievalChain
from langchain.vectorstores import Chroma, Pinecone
from langchain.embeddings.openai import OpenAIEmbeddings
import os
from langchain.memory import ConversationBufferMemory
from langchain.agents import load_tools, initialize_agent, AgentType
import ast
import openai
# Set up OpenAI API credentials
os.environ["OPENAI_API_KEY"] = "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"
openai.api_key='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'
os.environ["SERPAPI_API_KEY"] = "f7bbe11ca6d5cecd0b83065f649b5a12a0dca43ba4b829452dfe70cc4e62b20a"

llm=OpenAI(temperature=0,max_tokens=200)

tools = load_tools(["serpapi"],llm=llm)

PREFIX = '''You are the Associate and your role is to execute instructions of Manager which is another chatbot. You are excellent in giving detailed answers.
'''

FORMAT_INSTRUCTIONS = """To use a tool, please use the following format:
'''
Thought: Do I need to use a tool? Yes
Action: the action to take, should be one of [{tool_names}]
Action Input: the input to the action
Observation: the result of the action
'''

When you have gathered all the information regarding AI algorithm, just write it to the user in the form of a blog post.

'''
Thought: Do I need to use a tool? No
AI: [write a blog post]
'''
"""

SUFFIX = '''

Begin!

Previous conversation history:
{chat_history}

Instructions: {input}

'''

agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent="zero-shot-react-description",
    verbose=True,
    agent_kwargs={
        'prefix': PREFIX, 
#         'format_instructions': FORMAT_INSTRUCTIONS,
        'suffix': SUFFIX
    }
)

User_query = input('Please enter the query: ')

result = agent({"input": User_query.strip()})

# # create a memory object, which is neccessary to track the inputs/outputs and hold a conversation.
# memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
# # create a chain to answer questions 
# qa = ConversationalRetrievalChain.from_llm(OpenAI(temperature=0,max_tokens=200), retriever=retriever, memory=memory) # , memory=memory
# chat_history = []
# User_query = input('Please enter the query: ')

# result = qa({"question": User_query})  # , "chat_history": chat_history

def process_block(block):
    role_mapping = {
        'HumanMessage': 'user',
        'AIMessage': 'assistant'
    }

    result = []

    for message in block:
        role = role_mapping.get(type(message).__name__, type(message).__name__.lower())
        content = message.content.strip()
        result.append({'role': role, 'content': content})

    return result


def chat(messages):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        max_tokens=200,
        temperature=0
    )
#   response.choices[0].message["content"]
    return response.choices[0].message['content']


Mgr_content="""

You are the Manager and your role is to manager your associate Bot B, which is another chatbot.Generate prompts to guide your associate \
step by step to address user's request.You keep the conversation going with Associate trying to deep dive into the topic and consider the following conversation as well to see how can Bot A answer in a better way
"""

Supr_content="""

You are Supervisor. You are the Judge of this discussion, you evaluate the responses
and judge from scale 1 to 5 and give the score without any explanation based on below criteria :
If the response from Bot A is getting repeated or  \
there is no relevance to context or Bot A says "I don't know" then give score 2 or below.\
If the conversation is very good covering all points only then give score 5\
Your response should only be a number 1, 2, 3, 4, or 5

"""

# Initialize the chatbots

bot2_prompt = [{'role':'system', 'content': Mgr_content}]
bot3_prompt = [{'role':'system', 'content': Supr_content}]

# Get the initial context from the user
# context = [{'role':'user', 'content':result["answer"]}]
memory.save_context({'input': User_query},{"output": result["answer"]})
#result = qa({"question": bot1_prompt, "chat_history": context})

# Initialize the conversation tree
tree = []
bot2_response= ""
#bot1_response= []
# Chat loop
while True:
    # Bot 1 uses conversation retreival chain to generate response
    chat_history = [(User_query, result["answer"])]  
    #chat_history = [(b1_content, result["answer"])]
    
#     chat_history = [(b1_content, result["answer"])] + [(bot1_response, bot2_response)]
    # Added web search result to bot A response
    bot1_response = agent.run(bot2_response)
    print("Associate:", bot1_response)

    # Bot 2 questions to Bot 1
    
    messages = bot2_prompt + process_block(memory.load_memory_variables(())['chat_history'])  # + context
    bot2_response = chat(messages)
    # memory.save_context({'input': bot2_prompt},{"output": bot2_response})
    print("Manager:", bot2_response)
    
    # Bot 3 rates the conversation and gives response from 1 to 5
    
    messages = [{'role':'assistant', 'content':bot1_response}] + [{'role':'assistant', 'content':bot2_response}] + bot3_prompt
    bot3_response = chat(messages)
    print("Supervisor:", bot3_response)
    
    # Web Search bot gives reply to bot_2
    
#     bot4_response = agent.run(bot2_response)
#     memory.save_context({'input': bot2_response},{"output": bot4_response})
#     print("Bot D:", bot4_response)

    # Add the conversation to the tree
    tree.append(bot1_response)
    tree.append(bot2_response)
    tree_C = bot3_response
    
    # Check if the tree of thought has reached its end
    # if len(tree) >= 10:
    #   print("The tree of thought has reached its end.")
    #   break
    if tree_C == '5':
        print("The desired outcome is received as below: \n", "\n".join(tree_A))
        break
    if tree_C == '2' or tree_C == '1':
        User_input = input("Need Human intervention to keep the conversation going else enter 'stop' to exit ")
        if User_input.lower() == "stop":
            break
        else:
            bot2_response = User_input
            continue

# %% [markdown]
# # New test for managing aoociate bot by Manager bot

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage
from langchain.llms import OpenAI
from langchain import PromptTemplate
from langchain.chains import SequentialChain
from langchain.chains import ConversationChain
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.document_loaders import UnstructuredPDFLoader, OnlinePDFLoader, PyPDFLoader, TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import ConversationalRetrievalChain
from langchain.vectorstores import Chroma, Pinecone
from langchain.embeddings.openai import OpenAIEmbeddings
import os
from langchain.memory import ConversationBufferMemory
from langchain.agents import load_tools, initialize_agent, AgentType
import ast
import openai
# Set up OpenAI API credentials
os.environ["OPENAI_API_KEY"] = "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"
openai.api_key='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'
os.environ["SERPAPI_API_KEY"] = "f7bbe11ca6d5cecd0b83065f649b5a12a0dca43ba4b829452dfe70cc4e62b20a"



llm=OpenAI(temperature=0,max_tokens=200)

tools = load_tools(["serpapi"],llm=llm)
chat_history=[]

PREFIX = '''You are the Associate and your role is to execute instructions of Manager which is another chatbot. You are excellent in giving detailed answers.
'''

SUFFIX = '''

Begin!


Instructions: {input}
{agent_scratchpad}
'''

agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent="zero-shot-react-description",
#     verbose=True,
#     return_intermediate_steps=True,
    agent_kwargs={
        'prefix': PREFIX,
#         'format_instructions': FORMAT_INSTRUCTIONS,
         'suffix': SUFFIX
     }
)

User_query = input('Please enter the query: ')

result = agent({"input": User_query.strip(),"agent_scratchpad":[], "chat_history": []})

# result = agent({"input": User_query.strip()})

# # create a memory object, which is neccessary to track the inputs/outputs and hold a conversation.
# memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
# # create a chain to answer questions 
# qa = ConversationalRetrievalChain.from_llm(OpenAI(temperature=0,max_tokens=200), retriever=retriever, memory=memory) # , memory=memory
# chat_history = []
# User_query = input('Please enter the query: ')

# result = qa({"question": User_query})  # , "chat_history": chat_history

def process_block(block):
    role_mapping = {
        'HumanMessage': 'user',
        'AIMessage': 'assistant'
    }

    result = []

    for message in block:
        role = role_mapping.get(type(message).__name__, type(message).__name__.lower())
        content = message.content.strip()
        result.append({'role': role, 'content': content})

    return result


def chat(messages):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        max_tokens=200,
        temperature=0
    )
#   response.choices[0].message["content"]
    return response.choices[0].message['content']


Mgr_content="""

You are the Manager and your role is to manager your associate Bot B, which is another chatbot.Generate prompts to guide your associate \
step by step to address user's request.
Step 1 - Ask associate bot if it understands user's question.
Step 2 - Ask associate bot in details about definition, uses, basic info about the topic.
Step 1 - Ask associate bot about advanced and more complicated aspects of this topic.
"""

Supr_content="""

You are Supervisor. You are the Judge of this discussion, you evaluate the responses
and judge from scale 1 to 5 and give the score without any explanation based on below criteria :
If the response from Bot A is getting repeated or  \
there is no relevance to context or Bot A says "I don't know" then give score 2 or below.\
If the conversation is very good covering all points only then give score 5\
Your response should only be a number 1, 2, 3, 4, or 5

"""

# Initialize the chatbots

bot2_prompt = [{'role':'system', 'content': Mgr_content}]
bot3_prompt = [{'role':'system', 'content': Supr_content}]

# Get the initial context from the user
# context = [{'role':'user', 'content':result["answer"]}]
memory.save_context({'input': User_query},{"output": result["output"]})
#result = qa({"question": bot1_prompt, "chat_history": context})

# Initialize the conversation tree
tree = []
bot2_response= ""
#bot1_response= []
# Chat loop
while True:
    # Bot 1 uses conversation retreival chain to generate response
    chat_history = [(User_query, result["output"])]  
    #chat_history = [(b1_content, result["answer"])]
    
#     chat_history = [(b1_content, result["answer"])] + [(bot1_response, bot2_response)]
    # Added web search result to bot A response
    bot1_response = agent.run(bot2_response)
    print("Associate:", bot1_response)

    # Bot 2 questions to Bot 1
    
    messages = bot2_prompt + process_block(memory.load_memory_variables(())['chat_history'])  # + context
    bot2_response = chat(messages)
    # memory.save_context({'input': bot2_prompt},{"output": bot2_response})
    print("Manager:", bot2_response)
    
    # Bot 3 rates the conversation and gives response from 1 to 5
    
    messages = [{'role':'assistant', 'content':bot1_response}] + [{'role':'assistant', 'content':bot2_response}] + bot3_prompt
    bot3_response = chat(messages)
    print("Supervisor:", bot3_response)
    
    # Web Search bot gives reply to bot_2
    
#     bot4_response = agent.run(bot2_response)
#     memory.save_context({'input': bot2_response},{"output": bot4_response})
#     print("Bot D:", bot4_response)

    # Add the conversation to the tree
    tree.append(bot1_response)
    tree.append(bot2_response)
    tree_C = bot3_response
    
    # Check if the tree of thought has reached its end
    # if len(tree) >= 10:
    #   print("The tree of thought has reached its end.")
    #   break
    if tree_C == '5':
        print("The desired outcome is received as below: \n", "\n".join(tree_A))
        break
    if tree_C == '2' or tree_C == '1':
        User_input = input("Need Human intervention to keep the conversation going else enter 'stop' to exit ")
        if User_input.lower() == "stop":
            break
        else:
            bot2_response = User_input
            continue
# Out:
# Please enter the query: what is AI
# Associate: The Centers for Disease Control and Prevention (CDC) is a reliable source of information on the coronavirus pandemic.
# Manager: Do you understand what AI is?
# Supervisor: 4
# Associate: Yes, I understand what AI is. Artificial Intelligence is the intelligence of machines or software, as opposed to the intelligence of human beings or animals.
# Manager: Do you understand what AI is?
# Supervisor: 5
# The desired outcome is received as below:
#   AI can be used for data analysis and prediction, as well as for automating certain tasks, such as robo-advisors, direct indexing, and chatbots.The current status of the coronavirus pandemic can be found on the World Health Organization Coronavirus disease situation dashboard, which includes interactive tools such as maps, epidemic curves, and other charts.
